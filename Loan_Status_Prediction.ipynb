# %% [markdown]
# # Loan Status Prediction
#
# This notebook demonstrates loan approval prediction using machine learning techniques.

# %% [markdown]
# ## Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data Collection and Processing

# %%
# loading the dataset to pandas DataFrame
loan_dataset = pd.read_csv("data_set_loan.csv")

# %%
# Check data type
print(type(loan_dataset))

# %%
# printing the first 5 rows of the dataframe
loan_dataset.head()

# %%
# number of rows and columns
loan_dataset.shape

# %%
# statistical measures
loan_dataset.describe()

# %%
# dropping the missing values
loan_dataset = loan_dataset.dropna()

# %% [markdown]
# ## Data Preprocessing

# %%
# label encoding
loan_dataset.replace({"Loan_Status":{'N':0,'Y':1}},inplace=True)

# %%
# replacing the value of 3+ to 4
loan_dataset = loan_dataset.replace(to_replace='3+', value=4)

# %%
# convert categorical columns to numerical values
loan_dataset.replace({'Married':{'No':0,'Yes':1},'Gender':{'Male':1,'Female':0},'Self_Employed':{'No':0,'Yes':1},
                      'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2},'Education':{'Graduate':1,'Not Graduate':0}},inplace=True)

# %%
# Display processed data
loan_dataset.head()

# %% [markdown]
# ## Model Training and Evaluation
#
# Note: This notebook demonstrates the initial data preprocessing steps for loan status prediction.
# Additional cells would be added for:
# - Feature and target separation
# - Train-test split
# - Model training (SVM, Random Forest, etc.)
# - Model evaluation
# - Predictions
